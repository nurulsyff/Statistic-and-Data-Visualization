# %% [markdown]
# # Data Visualization Practice with Python
# - melb_data.csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# scroll horizontal
pd.set_option('display.max_columns', 100)

# read exel
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN       Yarra   -37.7996    144.9984
# ...

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# runtime configuration (rc)
# setting default canvas and font size

# style
sns.set_style("darkgrid")

# figure size (ukuran canvas)
plt.rcParams["figure.figsize"] = (14,6)

# font size
small = 14
medium = 16
large = 18

plt.rc('font', size = small)          # controls default text sizes
plt.rc('axes', titlesize = small)     # fontsize of the axes title
plt.rc('axes', labelsize = medium)    # fontsize of the x and y labels
plt.rc('xtick', labelsize = small)    # fontsize of the tick labels
plt.rc('ytick', labelsize = small)    # fontsize of the tick labels
plt.rc('legend', fontsize = small)    # legend fontsize
plt.rc('figure', titlesize = large)   # fontsize of the figure title

# %% [markdown]
# # **No.1**

# %%
sns.histplot(df['Price'], bins=20 , kde=False);

# %%
# range of price per ticks
x_tick = np.linspace(0,9000000,21)
x_tick
# Out:
# array([      0.,  450000.,  900000., 1350000., 1800000., 2250000.,
#        2700000., 3150000., 3600000., 4050000., 4500000., 4950000.,
#        5400000., 5850000., 6300000., 6750000., 7200000., 7650000.,
#        8100000., 8550000., 9000000.])

# %%
# untuk batas tiap bin 
x_tick = np.linspace(0,9000000,21)
y_tick = np.arange(0,6001, 500)

# histplot
ax = sns.histplot(df['Price'], bins=20 , kde=False)
ax.set_xticks(x_tick)
ax.set_yticks(y_tick)

plt.title('Histogram of Price', fontdict={'size':18})
plt.xticks(rotation=70)
plt.show()

# %%
# check for outliers in 'Price' using boxplot
plt.figure(figsize=(14,3))
sns.boxplot(df['Price']);
# Out:
# C:\Users\Dio Rahmantio\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.describe()[['Price']].tail()
# Out:
#          Price
# min    85000.0
# 25%   650000.0
# 50%   903000.0
# 75%  1330000.0
# max  9000000.0

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# # **No.2**

# %%
# check how many unique value in 'Regionname'
df['Regionname'].nunique()
# Out:
# 8

# %%
# Average 'Price' based on 'Regionname'
# using seaborn barplot, count mean on y axis by default and grouping x axis by default

sns.barplot(data=df, x='Regionname', y='Price')
plt.xticks(rotation=90);

# %%
price_region = df.groupby(by='Regionname', as_index=False).mean()[['Regionname','Price']].sort_values(by='Price', ascending=False)
price_region
# Out:
#                    Regionname         Price
# 5       Southern Metropolitan  1.372963e+06
# 0        Eastern Metropolitan  1.104080e+06
# 4  South-Eastern Metropolitan  9.229438e+05
# 2       Northern Metropolitan  8.981711e+05
# 6        Western Metropolitan  8.664205e+05
# 1            Eastern Victoria  6.999808e+05
# 3           Northern Victoria  5.948293e+05
# 7            Western Victoria  3.975234e+05

# %%
# Average 'Price' based on 'Regionname' sort Descending
# Barplot 
sns.barplot(data=price_region, x='Regionname', y='Price')

plt.xticks(rotation=90);

# %% [markdown]
# # **No.3**

# %%
# Number of houses for every 'Type'

df['Type'].value_counts()
# Out:
# h    9449
# u    3017
# t    1114
# Name: Type, dtype: int64

# %%
# plotting using count plot, to count value for every categories in x axis

sns.countplot(data=df, x='Type')
plt.ylabel('Jumlah Rumah')
# Out:
# Text(0, 0.5, 'Jumlah Rumah')

# %%
sns.barplot(data=df, x='Type', y='Price', estimator=len)
plt.ylabel('Jumlah Rumah')
# Out:
# Text(0, 0.5, 'Jumlah Rumah')

# %% [markdown]
# # **No.4**

# %%
# Relationship between 'Rooms', 'Price', 'Distance', 'BuildingArea', 'YearBuilt' using heatmap
# Which variable have the strongest correlation with 'Price'?

df_corr = df[['Rooms', 'Price', 'Distance', 'BuildingArea', 'YearBuilt']].corr('spearman')
df_corr
# Out:
#                  Rooms     Price  Distance  BuildingArea  YearBuilt
# Rooms         1.000000  0.539886  0.351416      0.775193  -0.072058
# Price         0.539886  1.000000 -0.129990      0.631425  -0.368080
# Distance      0.351416 -0.129990  1.000000      0.287116   0.228634
# BuildingArea  0.775193  0.631425  0.287116      1.000000   0.003002
# YearBuilt    -0.072058 -0.368080  0.228634      0.003002   1.000000

# %%
sns.heatmap(df_corr, annot=True, center=0, square=True, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
# variable 'BuildingArea' has the most correlation with 'Price'
sns.heatmap(df_corr.loc[['Price']], annot=True, center=0, square=True, cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df[['Rooms', 'Price', 'Distance', 'BuildingArea', 'YearBuilt']])

# %% [markdown]
# # **No.5**

# %%
# correlation between 'BuildingArea' and 'Price'
# first we need to exclude 'BuildingArea' greater than 2000 m2 because it is considered an outlier

# Correlation
df.corr('spearman')['Price']['BuildingArea']
# Out:
# 0.6314247475827348

# %%
# determine outlier
outlier = df[df['BuildingArea']>2000].index

# %%
# visualize using scatterplot to s
sns.scatterplot(data=df.drop(index=outlier), x='BuildingArea', y='Price');

# %% [markdown]
# # **No.6**

# %%
# Adding 'Type' as hue, so we can also observe the correlation of 'BuildingArea' and 'Price' based on the 'Type'
sns.scatterplot(data=df.drop(index=outlier), x='BuildingArea', y='Price', hue='Type');

# h - house,cottage,villa, semi,terrace
# u - unit, duplex
# t - townhouse

# %% [markdown]
# # **No.7**

# %%
# Change in number of house on sale from Jan 2016 - Dec 2017
# Change column Date from object to datetime
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0       2016-03-12
# 1       2016-04-02
# 2       2017-04-03
# 3       2017-04-03
# 4       2016-04-06
#            ...
# 13575   2017-08-26
# 13576   2017-08-26
# 13577   2017-08-26
# 13578   2017-08-26
# 13579   2017-08-26
# Name: Date, Length: 13580, dtype: datetime64[ns]

# %%
plt.figure(figsize=(24,8))

sns.lineplot(data=df, x='Date', y='Address', estimator=len)

plt.ylabel('Jumlah Rumah')
plt.title('Perubahan Jumlah Rumah yang Dijual Jan 2016-Des 2017')
# Out:
# Text(0.5, 1.0, 'Perubahan Jumlah Rumah yang Dijual Jan 2016-Des 2017')

# %%
# Only take the month and year
df['Month'] = pd.to_datetime(df['Date']).dt.to_period('M').apply(lambda x: str(x))
df['Month']
# Out:
# 0        2016-03
# 1        2016-04
# 2        2017-04
# 3        2017-04
# 4        2016-04
#           ...
# 13575    2017-08
# 13576    2017-08
# 13577    2017-08
# 13578    2017-08
# 13579    2017-08
# Name: Month, Length: 13580, dtype: object

# %%
# Number of house on sale (Jan 2016 - Des 2017)
df_monthly_price = df.groupby('Month', as_index=False).count()[['Month','Price']].rename(columns={'Price':'Number of House'})
df_monthly_price
# Out:
#       Month  Number of House
# 0   2016-01                2
# 1   2016-03              496
# 2   2016-04              558
# 3   2016-05              654
# 4   2016-06              626
# 5   2016-07              885
# 6   2016-08              813
# 7   2016-09              482
# 8   2016-10              854
# 9   2016-11              628
# 10  2016-12              338
# 11  2017-01              276
# 12  2017-02              333
# 13  2017-03              912
# 14  2017-04              688
# 15  2017-05              990
# 16  2017-06              843
# 17  2017-07              950
# 18  2017-08             1037
# 19  2017-09              706
# 20  2017-11              122
# 21  2017-12              387

# %%
plt.figure(figsize=(20,6))
sns.lineplot(data=df_monthly_price, x='Month', y='Number of House')
plt.xticks(rotation=90);

# %% [markdown]
# # **No.8**

# %%
# Show a visualization that illustrates the comparison of the distribution of house prices (Price) based on the type of house (Type)!

sns.boxplot(x=df['Price'], y='Type', data=df)

# %%
# At what price does a type 't' house can be considered an outlier?

# create a new dataframe of type 't' house and their price
df_type_t = df[df['Type']=='t'][['Price']]
df_type_t
# Out:
#            Price
# 21      900000.0
# 38      840000.0
# 42      700000.0
# 48      450000.0
# 56      700000.0
# ...          ...
# 13437   655000.0
# 13485  1655000.0
# 13504  1035000.0
# 13521  2455000.0
# 13526   640000.0
#
# [1114 rows x 1 columns]

# %%
plt.figure(figsize=(14,3))
sns.boxplot(df_type_t['Price'])

# %%
# formula to determine the outlier
q1 = df_type_t['Price'].quantile(0.25)
q3 = df_type_t['Price'].quantile(0.75)

IQR = q3 -q1
IQR 

upper = q3 + 1.5*IQR
lower = q1 - 1.5*IQR

print(f'Sebuah rumah bertipe "t" bisa dikatakan sebagai outlier jika harganya > {upper} atau < {lower}')
# Out:
# Sebuah rumah bertipe "t" bisa dikatakan sebagai outlier jika harganya > 1749750.0 atau < 22150.0

# %% [markdown]
# # **No.9**

# %%
import folium

# %%
# Show the location of the most expensive house on sale
# Mark it with a red pin icon, when you hover your mouse over the location it will say 'Home' and if you click it, the address will appear!
df[df['Price'] == df['Price'].max()]
# Out:
#          Suburb      Address  Rooms Type      Price Method SellerG       Date  \
# 12094  Mulgrave  35 Bevis St      3    h  9000000.0     PI    Hall 2017-07-29
#
#        Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 12094      18.8    3170.0       3.0       1.0  1.0     744.0         117.0
#
#        YearBuilt CouncilArea  Lattitude  Longtitude  \
# 12094     1960.0      Monash  -37.93168   145.16126
#
#                        Regionname  Propertycount    Month
# 12094  South-Eastern Metropolitan         7113.0  2017-07

# %%
# Open the coordinate on map
rumah = folium.Map(location=[-37.93168, 145.16126], zoom_start=15)

# For popup address
iframe = folium.IFrame('Address: 35 Bevis St')
myPopup = folium.Popup(iframe, min_width=200, max_width=0)

# For icon
myIcon = folium.Icon(color='red', icon='info-sign')

# Add Description
folium.Marker(
    location  = [-37.93168, 145.16126], 
    popup     = myPopup,
    tooltip   = 'Rumah',
    icon      = myIcon

).add_to(rumah)

rumah
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
